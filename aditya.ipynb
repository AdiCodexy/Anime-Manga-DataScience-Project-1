# %%
#score, episodes, aired, duration , rank, scored by change data types for formatting and analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('anime-dataset-2023.csv')
data["Episodes"] = data["Episodes"].replace("UNKNOWN", 0).astype(int)
data["Score"] = data["Score"].replace("UNKNOWN", 0).astype(float)
data["Rank"] = data["Rank"].replace("UNKNOWN", 0).astype(int)
data["Scored By"] = data["Scored By"].replace("UNKNOWN", 0).astype(int)
#Convert the column to 'object' type so it accepts strings alongside dates
data["Aired"] = data["Aired"].astype(object)
data["Aired"] = data["Aired"].fillna("UNKNOWN")
#Erase the extra text we don't need
clean_text = data["Duration"].str.replace(" per ep", "").replace("UNKNOWN", np.nan)
#Let pandas automatically calculate the time and convert to minutes
data["Duration_Minutes"] = pd.to_timedelta(clean_text, errors='coerce').dt.total_seconds() / 60
data = data.drop(columns=["Duration"])
data.to_csv('anime-dataset-2023.csv', index=False)

# %%
data["Aired"][848]
# Out:
# Timestamp('2005-08-06 00:00:00')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  str
#  2   English name  24905 non-null  str
#  3   Other name    24905 non-null  str
#  4   Score         24905 non-null  float64
#  5   Genres        24905 non-null  str
#  6   Synopsis      24905 non-null  str
#  7   Type          24905 non-null  str
#  8   Episodes      24905 non-null  int64
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  str
#  11  Status        24905 non-null  str
#  12  Producers     24905 non-null  str
#  13  Licensors     24905 non-null  str
#  14  Studios       24905 non-null  str
#  15  Source        24905 non-null  str
#  16  Duration      24905 non-null  str
#  17  Rating        24905 non-null  str
#  18  Rank          24905 non-null  int64
# ...

# %%
import pandas as pd
import numpy as np

# 1. Erase the extra text we don't need
clean_text = data["Duration"].str.replace(" per ep", "").replace("UNKNOWN", np.nan)

# 2. Let pandas automatically calculate the time and convert to minutes
data["Duration_Minutes"] = pd.to_timedelta(clean_text, errors='coerce').dt.total_seconds() / 60

# Check the results
print(data[["Duration", "Duration_Minutes"]].head(10))
# Out:
#         Duration  Duration_Minutes
# 0  24 min per ep              24.0
# 1    1 hr 55 min             115.0
# 2  24 min per ep              24.0
# 3  25 min per ep              25.0
# 4  23 min per ep              23.0
# 5  23 min per ep              23.0
# 6  23 min per ep              23.0
# 7  23 min per ep              23.0
# 8  27 min per ep              27.0
# 9  24 min per ep              24.0

# %%
data["Duration_Minutes"][24899]
# Out:
# np.float64(4.0)
