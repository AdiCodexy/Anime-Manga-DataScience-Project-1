# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('anime-dataset-2023.csv')
# Display the first few rows of the dataset
print(data.head())
# Check for missing values
print(data.isnull().sum())
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
data["Episodes"] = data["Episodes"].replace("UNKNOWN", 0)
data["Episodes"] = data["Episodes"].astype(int)

# %%
data["Episodes"][11]
# Out:
# np.int64(0)

# %%
data.query("Score=='UNKNOWN'")
# Out:
#        anime_id                        Name            English name  \
# 1578       1739  Shibawanko no Wa no Kokoro                 UNKNOWN
# 1699       1863     Silk Road Shounen Yuuto                 UNKNOWN
# 2476       2701         Susie-chan to Marvy  Little Susie and Marvy
# 2483       2708                  Wankorobee                 UNKNOWN
# 2508       2735        Mugen Senki Portriss                 UNKNOWN
# ...         ...                         ...                     ...
# 24900     55731                 Wu Nao Monu                 UNKNOWN
# 24901     55732         Bu Xing Si: Yuan Qi             Blader Soul
# 24902     55733                 Di Yi Xulie         The First Order
# 24903     55734    Bokura no Saishuu Sensou                 UNKNOWN
# 24904     55735              Shijuuku Nichi                 UNKNOWN
#
#          Other name    Score                              Genres  \
# 1578    しばわんこの和のこころ  UNKNOWN                             UNKNOWN
# ...

# %%
data["Score"] = data["Score"].replace("UNKNOWN", 0)
data["Score"] = data["Score"].astype(float)

# %%
data["Score"][1578]
# Out:
# np.float64(0.0)

# %%
data.query("Rank=='UNKNOWN'")
# Out:
#        anime_id                                       Name  \
# 165         188                              Gosenzo San'e
# 180         203                                Words Worth
# 188         211                                  Pure Mail
# 190         213                     Pia Carrot e Youkoso!!
# 191         214                   Pia Carrot e Youkoso!! 2
# ...         ...                                        ...
# 24880     55707                                     Kokoro
# 24881     55708                            Nazukeau Tabiji
# 24882     55709                       Boku to Roboko Movie
# 24883     55710  Hana-Doll*: Reinterpretation of Flowering
# 24900     55731                                Wu Nao Monu
#
#                   English name                              Other name  Score  \
# 165                 Masquerade                                   御先祖賛江   6.03
# 180                    UNKNOWN                                 ワーズ・ワース   6.72
# ...

# %%
data["Rank"] = data["Rank"].replace("UNKNOWN", 0)
data["Rank"] = data["Rank"].astype(int)

# %%
data.query("`Scored By`=='UNKNOWN'")
# Out:
#        anime_id                        Name            English name  \
# 1578       1739  Shibawanko no Wa no Kokoro                 UNKNOWN
# 1699       1863     Silk Road Shounen Yuuto                 UNKNOWN
# 2476       2701         Susie-chan to Marvy  Little Susie and Marvy
# 2483       2708                  Wankorobee                 UNKNOWN
# 2508       2735        Mugen Senki Portriss                 UNKNOWN
# ...         ...                         ...                     ...
# 24900     55731                 Wu Nao Monu                 UNKNOWN
# 24901     55732         Bu Xing Si: Yuan Qi             Blader Soul
# 24902     55733                 Di Yi Xulie         The First Order
# 24903     55734    Bokura no Saishuu Sensou                 UNKNOWN
# 24904     55735              Shijuuku Nichi                 UNKNOWN
#
#          Other name  Score                              Genres  \
# 1578    しばわんこの和のこころ    0.0                             UNKNOWN
# ...

# %%
data["Scored By"] = data["Scored By"].replace("UNKNOWN", 0)
data["Scored By"] = data["Scored By"].astype(int)

# %%
data["Scored By"][1578]
# Out:
# np.int64(0)

# %%
data["Aired"] = pd.to_datetime(
    data["Aired"],
    format="%b %d, %Y",
    errors="coerce"
)

# %%
data["Aired"]
# Out:
# 0              NaT
# 1       2001-09-01
# 2              NaT
# 3              NaT
# 4              NaT
#            ...
# 24900          NaT
# 24901          NaT
# 24902          NaT
# 24903   2022-04-23
# 24904   2022-09-05
# Name: Aired, Length: 24905, dtype: datetime64[us]
